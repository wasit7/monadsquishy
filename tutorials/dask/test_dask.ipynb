# %%
# pip install "dask[complete]"

# %%
from dask.distributed import LocalCluster
cluster = LocalCluster()          # Fully-featured local Dask cluster
client = cluster.get_client()
client
# Out:
# <Client: 'tcp://127.0.0.1:36285' processes=4 threads=8, memory=62.52 GiB>

# %%
import dask.dataframe as dd

# %%
ddf = dd.read_parquet('../dataset/simple.parquet')

# %%
ddf.repartition(npartitions=3)
# Out:
# Dask DataFrame Structure:
#               country    name order_date quantity   price
# npartitions=3
#                string  string     string   string  string
#                   ...     ...        ...      ...     ...
#                   ...     ...        ...      ...     ...
#                   ...     ...        ...      ...     ...
# Dask Name: repartition, 2 expressions
# Expr=Repartition(frame=ReadParquetFSSpec(a41633d), new_partitions=3)

# %%
ddf.info()
ddf.head()
# Out:
# <class 'dask_expr.DataFrame'>
# Columns: 5 entries, country to price
# dtypes: string(5)
#          country        name    order_date quantity             price
# 0             TH        มานี     9/25/2024   5 ชิ้น            $25.99
# 1  United States  John Smith      20240926  7 units         30.00 USD
# 2            ไทย        ปิติ    27-09-2024   pcs: 4      1,025.99 THB
# 3         อังกฤษ   Smith, J.  Sep 28, 2024       10  1,000,025.99 บาท
# 4   invalid name        J.S.  29 ก.ย. 2567      5pc         ๒๗.๙๙ บาท
